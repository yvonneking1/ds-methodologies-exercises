# %%
import pandas as pd
from datetime import timedelta, datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

from vega_datasets import data

#to make HTTP requests
import requests

import acquire

# %%
store = acquire.get_all_data()

# %%
store.head()
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
# 2013-01-01 00:00:00+00:00           2        1         13.0        1
# 2013-01-02 00:00:00+00:00           3        1         11.0        2
# 2013-01-02 00:00:00+00:00           4        1         11.0        2
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1095600 entries, 2013-01-01 00:00:00+00:00 to 2017-12-31 00:00:00+00:00
# Data columns (total 14 columns):
# Unnamed: 0       1095600 non-null int64
# item_id          1095600 non-null int64
# sale_amount      1095600 non-null float64
# sale_id          1095600 non-null int64
# store_id         1095600 non-null int64
# item_brand       1095600 non-null object
# item_name        1095600 non-null object
# item_price       1095600 non-null float64
# item_upc12       1095600 non-null int64
# item_upc14       1095600 non-null int64
# store_address    1095600 non-null object
# store_city       1095600 non-null object
# store_state      1095600 non-null object
# store_zipcode    1095600 non-null int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 125.4+ MB

# %% [markdown]
# 2. Plot the distribution of sale_amount and item_price.

# %%
sns.jointplot(store.sale_amount, store.item_price)

# %%
store.head()
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
# 2013-01-01 00:00:00+00:00           2        1         13.0        1
# 2013-01-02 00:00:00+00:00           3        1         11.0        2
# 2013-01-02 00:00:00+00:00           4        1         11.0        2
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# ...

# %%
store.head()
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
# 2013-01-01 00:00:00+00:00           2        1         13.0        1
# 2013-01-02 00:00:00+00:00           3        1         11.0        2
# 2013-01-02 00:00:00+00:00           4        1         11.0        2
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# ...

# %% [markdown]
# 4. Add a 'month' and 'day of week' column to your dataframe, derived from the index using the keywords for those date parts.m

# %%
store["month"] = store.index.month_name()

# %%
store.head(2)
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
#
#                             item_upc12   item_upc14           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00  35200264013  35200264013  12125 Alamo Ranch Pkwy
#
#                             store_city store_state  store_zipcode    month
# sale_date
# ...

# %%
store["day_of_week"] = store.index.day_name()

# %%
store.head(2)
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
#
#                             item_upc12   item_upc14           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00  35200264013  35200264013  12125 Alamo Ranch Pkwy
#
#                             store_city store_state  store_zipcode    month  \
# sale_date
# ...

# %% [markdown]
# 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
store["sales_total"] = store.sale_amount * store.item_price

# %% [markdown]
# 6. Using pandas.DataFrame.diff() function, create a new column that is the result of the current sales - the previous days sales.

# %%
store["sales_diff(1)"] = store.sales_total.diff(1)

# %%
store.head(2)
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
#
#                             item_upc12   item_upc14           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00  35200264013  35200264013  12125 Alamo Ranch Pkwy
#
#                             store_city store_state  store_zipcode    month  \
# sale_date
# ...

# %% [markdown]
# 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
def prep_store_data():
    #get the data from acquire file
    store = acquire.get_all_data()
    
    #Add a 'month' and 'day of week' column
    store["month"] = store.index.month_name()
    store["day_of_week"] = store.index.day_name()
    
    #Add sales total column from sale_amount and item_price
    store["sales_total"] = store.sale_amount * store.item_price
    
    #new column that is the result of the current sales - the previous days sales.
    store["sales_diff(1)"] = store.sales_total.diff(1)
    
    return store

# %%
store1 = prep_store_data()

# %%
store1.head()
# Out:
#                            Unnamed: 0  item_id  sale_amount  sale_id  \
# sale_date
# 2013-01-01 00:00:00+00:00           0        1         13.0        1
# 2013-01-01 00:00:00+00:00           1        1         13.0        1
# 2013-01-01 00:00:00+00:00           2        1         13.0        1
# 2013-01-02 00:00:00+00:00           3        1         11.0        2
# 2013-01-02 00:00:00+00:00           4        1         11.0        2
#
#                            store_id item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-01 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
# 2013-01-02 00:00:00+00:00         1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# ...

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# 1. Convert date column to datetime format.

# %%
ops = acquire.german_energy_csv()

# %%
ops.head(2)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN

# %%
ops["Date"] = pd.to_datetime(ops["Date"])

# %%
ops.head(2)
# Out:
#         Date  Consumption  Wind  Solar  Wind+Solar
# 0 2006-01-01     1069.184   NaN    NaN         NaN
# 1 2006-01-02     1380.521   NaN    NaN         NaN

# %% [markdown]
# 2. Plot the distribution of each of your variables

# %%
sns.pairplot(ops)

# %% [markdown]
# 3. Set the index to be the datetime variable.

# %%
ops = ops.sort_values("Date").set_index("Date")

# %%
ops.head(2)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN

# %% [markdown]
# 4. Add a month and a year column to your dataframe.

# %%
ops["month"] = ops.index.month_name()

# %%
ops.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar    month
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  January
# 2006-01-02     1380.521   NaN    NaN         NaN  January
# 2006-01-03     1442.533   NaN    NaN         NaN  January
# 2006-01-04     1457.217   NaN    NaN         NaN  January
# 2006-01-05     1477.131   NaN    NaN         NaN  January

# %%
ops["year"] = ops.index.year

# %%
ops.head(2)
# Out:
#             Consumption  Wind  Solar  Wind+Solar    month  year
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  January  2006
# 2006-01-02     1380.521   NaN    NaN         NaN  January  2006

# %% [markdown]
# 5. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results

# %%
def prep_german_energy():
    #get the data from acquire file
    ops = acquire.german_energy_csv()
    
    # Convert date column to datetime format.
    ops["Date"] = pd.to_datetime(ops["Date"])
    
    # Set the index to be the datetime variable.
    ops = ops.sort_values("Date").set_index("Date")
    
    #Add a month and a year column
    ops["month"] = ops.index.month_name()
    ops["year"] = ops.index.year
    
    return ops

# %%
df = prep_german_energy()

# %%
df
# Out:
#             Consumption     Wind   Solar  Wind+Solar     month  year
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN   January  2006
# 2006-01-02   1380.52100      NaN     NaN         NaN   January  2006
# 2006-01-03   1442.53300      NaN     NaN         NaN   January  2006
# 2006-01-04   1457.21700      NaN     NaN         NaN   January  2006
# 2006-01-05   1477.13100      NaN     NaN         NaN   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %% [markdown]
# **data.sf_temps()**
#
# Use the above dataset for the exercises below:

# %%
df = data.sf_temps()

# %%
df.head()
# Out:
#    temp                date
# 0  47.8 2010-01-01 00:00:00
# 1  47.4 2010-01-01 01:00:00
# 2  46.9 2010-01-01 02:00:00
# 3  46.5 2010-01-01 03:00:00
# 4  46.0 2010-01-01 04:00:00

# %%
df.shape
# Out:
# (8759, 2)

# %% [markdown]
# 1. Resample by the day and take the average temperature. Visualize the average temperature over time.

# %%
df.groupby("date").temp.mean()
# Out:
# date
# 2010-01-01 00:00:00    47.8
# 2010-01-01 01:00:00    47.4
# 2010-01-01 02:00:00    46.9
# 2010-01-01 03:00:00    46.5
# 2010-01-01 04:00:00    46.0
#                        ...
# 2010-12-31 19:00:00    50.4
# 2010-12-31 20:00:00    49.9
# 2010-12-31 21:00:00    49.4
# 2010-12-31 22:00:00    48.8
# 2010-12-31 23:00:00    48.3
# Name: temp, Length: 8759, dtype: float64

# %%
df.groupby("date").temp.mean().asfreq("D").plot()

# %% [markdown]
# 2. Write the code necessary to visualize the minimum temperature over time.

# %%
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x11bce1d40> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     125         for f_mgr in cls.get_all_fig_managers():
#     126             if force or f_mgr.canvas.figure.stale:
# --> 127                 f_mgr.canvas.draw_idle()
#     128
#     129 atexit.register(Gcf.destroy_all)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
# ...

# %% [markdown]
# 3. Write the code necessary to visualize the maximum temperature over time.

# %%
df.groupby("date").temp.max()
# Out:
# date
# 2010-01-01 00:00:00    47.8
# 2010-01-01 01:00:00    47.4
# 2010-01-01 02:00:00    46.9
# 2010-01-01 03:00:00    46.5
# 2010-01-01 04:00:00    46.0
#                        ...
# 2010-12-31 19:00:00    50.4
# 2010-12-31 20:00:00    49.9
# 2010-12-31 21:00:00    49.4
# 2010-12-31 22:00:00    48.8
# 2010-12-31 23:00:00    48.3
# Name: temp, Length: 8759, dtype: float64

# %%
df.groupby("date").temp.max().asfreq("D").plot()

# %% [markdown]
# 6. Resample by the day and calculate the min and max temp for the day (Hint: .agg(['min', 'max'])). Use this resampled dataframe to calculate the change in temperature for the day. Which month has the highest daily temperature variability?

# %%
df.groupby("date").temp.agg(["min", "max"]).asfreq("D").plot()
